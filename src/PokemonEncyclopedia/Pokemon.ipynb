# %% [markdown]
# ## In order to reduce the number of call of API, we decided to save this url to local.
# ### Fixed limit: 100 API requests per IP address per minute

# %%
import requests
import json
import collections
import time
import concurrent.futures
import csv
import functools
from pprint import pprint
from typing import List, Dict
from IPython.display import clear_output

# %% [markdown]
# Each pokemon has many different json files with different information. This will run through each pokemon in each json type (input) and save them as a csv file. This is how it looks like at the end:
#
# ```
# bulbasaur,https://pokeapi.co/api/v2/pokemon-species/1/
# ivysaur,https://pokeapi.co/api/v2/pokemon-species/2/
# venusaur,https://pokeapi.co/api/v2/pokemon-species/3/
# charmander,https://pokeapi.co/api/v2/pokemon-species/4/
# charmeleon,https://pokeapi.co/api/v2/pokemon-species/5/
# charizard,https://pokeapi.co/api/v2/pokemon-species/6/
# squirtle,https://pokeapi.co/api/v2/pokemon-species/7/
# wartortle,https://pokeapi.co/api/v2/pokemon-species/8/
# blastoise,https://pokeapi.co/api/v2/pokemon-species/9/
# caterpie,https://pokeapi.co/api/v2/pokemon-species/10/
# ...
# ```

# %%
def request_and_save_urls(json_type: str):
    # Each url only has 20 pokemons
    url = fr"https://pokeapi.co/api/v2/{json_type}/"
    with open(f"data/{json_type}/{json_type}-urls.csv", "w") as file:
        pokemon_url_writer = csv.writer(file, delimiter=",", lineterminator="\n")

        while 1:
            # Get urls of 20 pokemons
            response = requests.get(url)
            json_data = json.loads(response.text)

            # Write to CSV file
            for pokemon in json_data["results"]:
                pokemon_url_writer.writerow(list(pokemon.values()))

            # Next 20 pokemons
            url = json_data["next"]
            if not url: break

# %% [markdown]
# ### We want the following json files

# %%
request_and_save_urls("pokemon")
request_and_save_urls("pokemon-species")
request_and_save_urls("type")

# %% [markdown]
# ### Load the csv file and request each Pokemon
# This is used to fetch data from pokeAPI and save it locally. We load the CSV file earlier and request each Pokemon information. We group all information by type (pokemon_species, ...) and save it as a JSON file. However, because of the **fixed limit** on how many API can be called per minute (100), there is a delay in the code which make the total run time between 15-20 minutes
#
# We also have an exclusion list to exclude data that are not needed from the responsed JSON

# %%
def request_and_cache(json_type, exclude: List[str]) -> None:
    return_json = {}
    
    # Open csv file to get urls
    pokemon_urls = list(csv.reader(open(f"data/{json_type}/{json_type}-urls.csv", "r"), delimiter=","))
    
    # Request each url and save as 1 big json file
    for i, (pokemon_name, pokemon_url) in enumerate(pokemon_urls):
        clear_output()
        print(f"{i}. Working on type: '{json_type}', pokemon: {pokemon_name}")
        try:
            pokemon_json = json.loads(requests.get(pokemon_url).text)
        except:
            continue
        
        # To reduce the file size, we exclude some parts of json_data
        return_json[pokemon_name] = {k:v for k, v in pokemon_json.items() if k not in exclude}
        
        # Make sure not to exceed to API limit
        time.sleep(0.4)
    json.dump(return_json, open(f"data/{json_type}/{json_type}.json", "w"))

# %% [markdown]
# We use multithreading to make this process faster (Not really), need to change the logic

# %%
# Single Run
# request_and_cache("pokemon",["game_indices", "moves"])
with concurrent.futures.ThreadPoolExecutor(max_workers=3) as executor:
    for json_type, exclude in [("pokemon", ["game_indices", 
                                            "moves", 
                                            ]), 
                               ("pokemon-species", ["genera", 
                                                    "names", 
                                                    "pokedex_numbers", 
                                                    "varieties", 
                                                    "flavor_text_entries",
                                                   ]),
                               ("type", ["game_indices", 
                                         "generation", 
                                         "id",
                                         "move_damage_class",
                                         "moves",
                                         "names",
                                         "pokemon"
                                            ]),
                               ]:
        temp = functools.partial(request_and_cache, exclude=exclude)
        executor.map(temp, [json_type])
# Out:
# 0. Working on type: 'pokemon', pokemon: bulbasaur
# 0. Working on type: 'pokemon-species', pokemon: bulbasaur
# 0. Working on type: 'type', pokemon: normal
# 1. Working on type: 'pokemon-species', pokemon: ivysaur
# 1. Working on type: 'type', pokemon: fighting
# 1. Working on type: 'pokemon', pokemon: ivysaur
# 2. Working on type: 'pokemon-species', pokemon: venusaur
# 2. Working on type: 'pokemon', pokemon: venusaur
# 2. Working on type: 'type', pokemon: flying
# 3. Working on type: 'pokemon', pokemon: charmander
# 3. Working on type: 'type', pokemon: poison
# 3. Working on type: 'pokemon-species', pokemon: charmander
# 4. Working on type: 'pokemon', pokemon: charmeleon
# 4. Working on type: 'pokemon-species', pokemon: charmeleon
# 4. Working on type: 'type', pokemon: ground
# 5. Working on type: 'pokemon-species', pokemon: charizard
# 5. Working on type: 'type', pokemon: rock
# 5. Working on type: 'pokemon', pokemon: charizard
# 6. Working on type: 'pokemon-species', pokemon: squirtle
# 6. Working on type: 'type', pokemon: bug
# 6. Working on type: 'pokemon', pokemon: squirtle
# 7. Working on type: 'pokemon-species', pokemon: wartortle
# 7. Working on type: 'type', pokemon: ghost
# 7. Working on type: 'pokemon', pokemon: wartortle
# 8. Working on type: 'pokemon-species', pokemon: blastoise
# 8. Working on type: 'type', pokemon: steel
# 8. Working on type: 'pokemon', pokemon: blastoise
# 9. Working on type: 'pokemon-species', pokemon: caterpie
# 9. Working on type: 'type', pokemon: fire
# 9. Working on type: 'pokemon', pokemon: caterpie
# 10. Working on type: 'type', pokemon: water
# 10. Working on type: 'pokemon-species', pokemon: metapod
# 10. Working on type: 'pokemon', pokemon: metapod
# 11. Working on type: 'type', pokemon: grass
# 11. Working on type: 'pokemon', pokemon: butterfree
# 11. Working on type: 'pokemon-species', pokemon: butterfree
# 12. Working on type: 'type', pokemon: electric
# 12. Working on type: 'pokemon', pokemon: weedle
# 12. Working on type: 'pokemon-species', pokemon: weedle
# 13. Working on type: 'pokemon-species', pokemon: kakuna
# 13. Working on type: 'pokemon', pokemon: kakuna
# 13. Working on type: 'type', pokemon: psychic
# 14. Working on type: 'type', pokemon: ice
# 14. Working on type: 'pokemon', pokemon: beedrill
# 14. Working on type: 'pokemon-species', pokemon: beedrill
# 15. Working on type: 'type', pokemon: dragon
# 15. Working on type: 'pokemon-species', pokemon: pidgey
# 15. Working on type: 'pokemon', pokemon: pidgey
# 16. Working on type: 'pokemon-species', pokemon: pidgeotto
# 16. Working on type: 'type', pokemon: dark
# 16. Working on type: 'pokemon', pokemon: pidgeotto
# 17. Working on type: 'type', pokemon: fairy
# 17. Working on type: 'pokemon', pokemon: pidgeot
# 17. Working on type: 'pokemon-species', pokemon: pidgeot
# 18. Working on type: 'pokemon-species', pokemon: rattata
# 18. Working on type: 'type', pokemon: unknown
# 18. Working on type: 'pokemon', pokemon: rattata
# 19. Working on type: 'pokemon-species', pokemon: raticate
# 19. Working on type: 'pokemon', pokemon: raticate
# 19. Working on type: 'type', pokemon: shadow
# 20. Working on type: 'pokemon-species', pokemon: spearow
# 20. Working on type: 'pokemon', pokemon: spearow
# 21. Working on type: 'pokemon-species', pokemon: fearow
# 21. Working on type: 'pokemon', pokemon: fearow
# 22. Working on type: 'pokemon-species', pokemon: ekans
# 22. Working on type: 'pokemon', pokemon: ekans
# 23. Working on type: 'pokemon-species', pokemon: arbok
# 23. Working on type: 'pokemon', pokemon: arbok
# 24. Working on type: 'pokemon-species', pokemon: pikachu
# 24. Working on type: 'pokemon', pokemon: pikachu
# 25. Working on type: 'pokemon-species', pokemon: raichu
# 25. Working on type: 'pokemon', pokemon: raichu
# 26. Working on type: 'pokemon-species', pokemon: sandshrew
# 26. Working on type: 'pokemon', pokemon: sandshrew
# 27. Working on type: 'pokemon-species', pokemon: sandslash
# 27. Working on type: 'pokemon', pokemon: sandslash
# 28. Working on type: 'pokemon-species', pokemon: nidoran-f
# 28. Working on type: 'pokemon', pokemon: nidoran-f
# 29. Working on type: 'pokemon-species', pokemon: nidorina
# 29. Working on type: 'pokemon', pokemon: nidorina
# 30. Working on type: 'pokemon-species', pokemon: nidoqueen
# 30. Working on type: 'pokemon', pokemon: nidoqueen
# 31. Working on type: 'pokemon-species', pokemon: nidoran-m
# 31. Working on type: 'pokemon', pokemon: nidoran-m
# 32. Working on type: 'pokemon-species', pokemon: nidorino
# 32. Working on type: 'pokemon', pokemon: nidorino
# 33. Working on type: 'pokemon-species', pokemon: nidoking
# 33. Working on type: 'pokemon', pokemon: nidoking
# 34. Working on type: 'pokemon-species', pokemon: clefairy
# 34. Working on type: 'pokemon', pokemon: clefairy
# 35. Working on type: 'pokemon', pokemon: clefable
# 35. Working on type: 'pokemon-species', pokemon: clefable
# 36. Working on type: 'pokemon', pokemon: vulpix
# 36. Working on type: 'pokemon-species', pokemon: vulpix
# 37. Working on type: 'pokemon', pokemon: ninetales
# 37. Working on type: 'pokemon-species', pokemon: ninetales
# 38. Working on type: 'pokemon', pokemon: jigglypuff
# 38. Working on type: 'pokemon-species', pokemon: jigglypuff
# 39. Working on type: 'pokemon', pokemon: wigglytuff
# 39. Working on type: 'pokemon-species', pokemon: wigglytuff
# 40. Working on type: 'pokemon', pokemon: zubat
# 40. Working on type: 'pokemon-species', pokemon: zubat
# 41. Working on type: 'pokemon', pokemon: golbat
# 41. Working on type: 'pokemon-species', pokemon: golbat
# 42. Working on type: 'pokemon', pokemon: oddish
# 42. Working on type: 'pokemon-species', pokemon: oddish
# 43. Working on type: 'pokemon', pokemon: gloom
# 43. Working on type: 'pokemon-species', pokemon: gloom
# 44. Working on type: 'pokemon', pokemon: vileplume
# 44. Working on type: 'pokemon-species', pokemon: vileplume
# 45. Working on type: 'pokemon', pokemon: paras
# 45. Working on type: 'pokemon-species', pokemon: paras
# 46. Working on type: 'pokemon', pokemon: parasect
# 46. Working on type: 'pokemon-species', pokemon: parasect
# 47. Working on type: 'pokemon', pokemon: venonat
# 47. Working on type: 'pokemon-species', pokemon: venonat
# 48. Working on type: 'pokemon', pokemon: venomoth
# 48. Working on type: 'pokemon-species', pokemon: venomoth
# 49. Working on type: 'pokemon', pokemon: diglett
# 49. Working on type: 'pokemon-species', pokemon: diglett
# 50. Working on type: 'pokemon', pokemon: dugtrio
# 50. Working on type: 'pokemon-species', pokemon: dugtrio
# 51. Working on type: 'pokemon', pokemon: meowth
# 51. Working on type: 'pokemon-species', pokemon: meowth
# 52. Working on type: 'pokemon', pokemon: persian
# 52. Working on type: 'pokemon-species', pokemon: persian
# 53. Working on type: 'pokemon', pokemon: psyduck
# 53. Working on type: 'pokemon-species', pokemon: psyduck
# 54. Working on type: 'pokemon', pokemon: golduck
# 54. Working on type: 'pokemon-species', pokemon: golduck
# 55. Working on type: 'pokemon', pokemon: mankey
# 55. Working on type: 'pokemon-species', pokemon: mankey
# 56. Working on type: 'pokemon', pokemon: primeape
# 56. Working on type: 'pokemon-species', pokemon: primeape
# 57. Working on type: 'pokemon', pokemon: growlithe
# 57. Working on type: 'pokemon-species', pokemon: growlithe
# 58. Working on type: 'pokemon', pokemon: arcanine
# 58. Working on type: 'pokemon-species', pokemon: arcanine
# 59. Working on type: 'pokemon', pokemon: poliwag
# 59. Working on type: 'pokemon-species', pokemon: poliwag
# 60. Working on type: 'pokemon', pokemon: poliwhirl
# 60. Working on type: 'pokemon-species', pokemon: poliwhirl
# 61. Working on type: 'pokemon', pokemon: poliwrath
# 61. Working on type: 'pokemon-species', pokemon: poliwrath
# 62. Working on type: 'pokemon', pokemon: abra
# 62. Working on type: 'pokemon-species', pokemon: abra
# 63. Working on type: 'pokemon', pokemon: kadabra
# 63. Working on type: 'pokemon-species', pokemon: kadabra
# 64. Working on type: 'pokemon', pokemon: alakazam
# 64. Working on type: 'pokemon-species', pokemon: alakazam
# 65. Working on type: 'pokemon', pokemon: machop
# 65. Working on type: 'pokemon-species', pokemon: machop
# 66. Working on type: 'pokemon', pokemon: machoke
# 66. Working on type: 'pokemon-species', pokemon: machoke
# 67. Working on type: 'pokemon', pokemon: machamp
# 67. Working on type: 'pokemon-species', pokemon: machamp
# 68. Working on type: 'pokemon', pokemon: bellsprout
# 68. Working on type: 'pokemon-species', pokemon: bellsprout
# 69. Working on type: 'pokemon', pokemon: weepinbell
# 69. Working on type: 'pokemon-species', pokemon: weepinbell
# 70. Working on type: 'pokemon', pokemon: victreebel
# 70. Working on type: 'pokemon-species', pokemon: victreebel
# 71. Working on type: 'pokemon-species', pokemon: tentacool
# 71. Working on type: 'pokemon', pokemon: tentacool
# 72. Working on type: 'pokemon-species', pokemon: tentacruel
# 72. Working on type: 'pokemon', pokemon: tentacruel
# 73. Working on type: 'pokemon-species', pokemon: geodude
# 73. Working on type: 'pokemon', pokemon: geodude
# 74. Working on type: 'pokemon-species', pokemon: graveler
# 74. Working on type: 'pokemon', pokemon: graveler
# 75. Working on type: 'pokemon-species', pokemon: golem
# 75. Working on type: 'pokemon', pokemon: golem
# 76. Working on type: 'pokemon-species', pokemon: ponyta
# 76. Working on type: 'pokemon', pokemon: ponyta
# 77. Working on type: 'pokemon-species', pokemon: rapidash
# 77. Working on type: 'pokemon', pokemon: rapidash
# 78. Working on type: 'pokemon-species', pokemon: slowpoke
# 78. Working on type: 'pokemon', pokemon: slowpoke
# 79. Working on type: 'pokemon-species', pokemon: slowbro
# 79. Working on type: 'pokemon', pokemon: slowbro
# 80. Working on type: 'pokemon-species', pokemon: magnemite
# 80. Working on type: 'pokemon', pokemon: magnemite
# 81. Working on type: 'pokemon-species', pokemon: magneton
# 81. Working on type: 'pokemon', pokemon: magneton
# 82. Working on type: 'pokemon-species', pokemon: farfetchd
# 82. Working on type: 'pokemon', pokemon: farfetchd
# 83. Working on type: 'pokemon-species', pokemon: doduo
# 83. Working on type: 'pokemon', pokemon: doduo
# 84. Working on type: 'pokemon-species', pokemon: dodrio
# 84. Working on type: 'pokemon', pokemon: dodrio
# 85. Working on type: 'pokemon-species', pokemon: seel
# 85. Working on type: 'pokemon', pokemon: seel
# 86. Working on type: 'pokemon-species', pokemon: dewgong
# 86. Working on type: 'pokemon', pokemon: dewgong
# 87. Working on type: 'pokemon-species', pokemon: grimer
# 87. Working on type: 'pokemon', pokemon: grimer
# 88. Working on type: 'pokemon-species', pokemon: muk
# 88. Working on type: 'pokemon', pokemon: muk
# 89. Working on type: 'pokemon-species', pokemon: shellder
# 89. Working on type: 'pokemon', pokemon: shellder
# 90. Working on type: 'pokemon-species', pokemon: cloyster
# 90. Working on type: 'pokemon', pokemon: cloyster
# 91. Working on type: 'pokemon-species', pokemon: gastly
# 91. Working on type: 'pokemon', pokemon: gastly
# 92. Working on type: 'pokemon-species', pokemon: haunter
# 92. Working on type: 'pokemon', pokemon: haunter
# 93. Working on type: 'pokemon-species', pokemon: gengar
# 93. Working on type: 'pokemon', pokemon: gengar
# 94. Working on type: 'pokemon-species', pokemon: onix
# 94. Working on type: 'pokemon', pokemon: onix
# 95. Working on type: 'pokemon-species', pokemon: drowzee
# 95. Working on type: 'pokemon', pokemon: drowzee
# 96. Working on type: 'pokemon-species', pokemon: hypno
# 96. Working on type: 'pokemon', pokemon: hypno
# 97. Working on type: 'pokemon-species', pokemon: krabby
# 98. Working on type: 'pokemon-species', pokemon: kingler
# 97. Working on type: 'pokemon', pokemon: krabby
# 99. Working on type: 'pokemon-species', pokemon: voltorb
# 98. Working on type: 'pokemon', pokemon: kingler
# 100. Working on type: 'pokemon-species', pokemon: electrode
# 99. Working on type: 'pokemon', pokemon: voltorb
# 101. Working on type: 'pokemon-species', pokemon: exeggcute
# 100. Working on type: 'pokemon', pokemon: electrode
# 102. Working on type: 'pokemon-species', pokemon: exeggutor
# 101. Working on type: 'pokemon', pokemon: exeggcute
# 103. Working on type: 'pokemon-species', pokemon: cubone
# 102. Working on type: 'pokemon', pokemon: exeggutor
# 104. Working on type: 'pokemon-species', pokemon: marowak
# 103. Working on type: 'pokemon', pokemon: cubone
# 105. Working on type: 'pokemon-species', pokemon: hitmonlee
# 104. Working on type: 'pokemon', pokemon: marowak
# 106. Working on type: 'pokemon-species', pokemon: hitmonchan
# 105. Working on type: 'pokemon', pokemon: hitmonlee
# 106. Working on type: 'pokemon', pokemon: hitmonchan
# 107. Working on type: 'pokemon-species', pokemon: lickitung
# 108. Working on type: 'pokemon-species', pokemon: koffing
# 107. Working on type: 'pokemon', pokemon: lickitung
# 109. Working on type: 'pokemon-species', pokemon: weezing
# 108. Working on type: 'pokemon', pokemon: koffing
# 110. Working on type: 'pokemon-species', pokemon: rhyhorn
# 109. Working on type: 'pokemon', pokemon: weezing
# 111. Working on type: 'pokemon-species', pokemon: rhydon
# 110. Working on type: 'pokemon', pokemon: rhyhorn
# 112. Working on type: 'pokemon-species', pokemon: chansey
# 111. Working on type: 'pokemon', pokemon: rhydon
# 113. Working on type: 'pokemon-species', pokemon: tangela
# 112. Working on type: 'pokemon', pokemon: chansey
# 114. Working on type: 'pokemon-species', pokemon: kangaskhan
# 113. Working on type: 'pokemon', pokemon: tangela
# 115. Working on type: 'pokemon-species', pokemon: horsea
# 114. Working on type: 'pokemon', pokemon: kangaskhan

# %% [markdown]
# ### Load Pokemon Json files and Analyse

# %% [markdown]
# #### Pokemon

# %%
all_pokemons_info = collections.defaultdict(dict)

pokemon_json = json.load(open("data/pokemon/pokemon.json", "r"))
for pokemon, info in pokemon_json.items():
    pokemon_info = all_pokemons_info[pokemon]
    
    # Get height, weight, name
    for key in ("height", "weight", "name"):
        pokemon_info[key] = info[key]
        
    # Get 6 stats (hp, att, def, sp. att, sp. def) for pokemon
    for stats in info["stats"]:
        pokemon_info[stats["stat"]["name"]] = stats["base_stat"]
    
    # Get list of abilities
    pokemon_info["abilities"] = [ability["ability"]["name"] for ability in info["abilities"]]
    
    # Get Pokemon Image
    pokemon_info["sprites"] = info["sprites"]["front_default"]
    
    # Get Pokemon Types
    pokemon_info["types"] = [type_["type"]["name"] for type_ in info["types"]]
    
    # Get Pokemon Species Name
    pokemon_info["species"] = info["species"]["name"]

# %% [markdown]
# #### Pokemon Species

# %%
pokemon_species_json = json.load(open("data/pokemon-species/pokemon-species.json", "r"))
for pokemon, info in pokemon_species_json.items():
    pokemon_info = all_pokemons_info[pokemon]
    
    # Get basic info
    for key in ("base_happiness", "capture_rate", "gender_rate"):
        pokemon_info[key] = info[key]
    
    # Get list of egg groups
    pokemon_info["egg_groups"] = [group["name"] for group in info["egg_groups"]]
    
    # Get Evolution Chain
    if info["evolves_from_species"]:
        pokemon_info["evolves_from"] = info["evolves_from_species"]["name"]
        prev_pokemon = all_pokemons_info[pokemon_info["evolves_from"]]
        prev_pokemon["evolves_to"] = prev_pokemon.get("evolves_to", []) + [pokemon]    
        
    # Get basic info. These info are in a dictionary
    for key in ("color", "growth_rate", "habitat", "shape"):
        if info[key]: pokemon_info[key] = info[key]["name"]
            
    # Get Generation. Format: "generation-iii". Need to convert to uppercase Roman numerals
    pokemon_info["generation"] = info["generation"]["name"].split("-")[-1].upper()

# %% [markdown]
# ### Save data as a JSON file

# %%
json.dump(all_pokemons_info, open("data/all_pokemons_info.json", "w"))

# %% [markdown]
# ### Create CSV file from JSON.

# %%
all_pokemons_info_csv = []

with open("data/all_pokemons_info.csv", "w") as csv_file:
    writer = csv.writer(csv_file, delimiter=",", lineterminator="\n")
    for pokemon, info in all_pokemons_info.items():
        try:
            writer.writerow([info["sprites"],
                             pokemon,
                             ", ".join(info["types"]),
                             info["hp"],
                             info["attack"],
                             info["defense"],
                             info["special-attack"],
                             info["special-defense"],
                             info["speed"],
                             ", ".join(info["abilities"]),
    #                         info["base_happiness"],
    #                         info["capture_rate"],
                             info["height"]*10,
                             info["weight"]/10,])
        except:
            print(pokemon, end=", ")
# Out:
# exeggutor, deoxys, wormadam, giratina, shaymin, basculin, darmanitan, tornadus, thundurus, landorus, keldeo, meloetta, meowstic, aegislash, pumpkaboo, gourgeist, oricorio, lycanroc, wishiwashi, minior, mimikyu, toxtricity, eiscue, indeedee, zacian, zamazenta, urshifu,

# %% [markdown]
# # Print using CSV

# %%
from IPython.display import HTML, display
import tabulate
import pandas as pd

content = [["#", "Sprite", "Name", "Types", 
            "HP", "Att", "Def", "Sp. Att", "Sp. Def", "Speed", 
            "Abilities",
            "Height (cm)", "Weight (kg)"]]
with open("data/all_pokemons_info.csv", "r") as csv_file:
    csv_data = csv.reader(csv_file)
    for index, info in enumerate(csv_data):
        sprites, pokemon, types, hp, attack, defense, special_attack, special_defense, speed, abilities, height, weight = info
        content.append([index + 1,
                        f"<img src='{sprites}' alt='{pokemon}'",
                        pokemon,
                        types,
                        hp,
                        attack,
                        defense,
                        special_attack,
                        special_defense,
                        speed,
                        abilities,
                        height,
                        weight,
                       ])
        
display(HTML(tabulate.tabulate(content[:10], 
                               headers='firstrow', 
                               tablefmt='html',)))
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  #</th><th>Sprite                                                                                                    </th><th>Name      </th><th>Types        </th><th style="text-align: right;">  HP</th><th style="text-align: right;">  Att</th><th style="text-align: right;">  Def</th><th style="text-align: right;">  Sp. Att</th><th style="text-align: right;">  Sp. Def</th><th style="text-align: right;">  Speed</th><th>Abilities            </th><th style="text-align: right;">  Height (cm)</th><th style="text-align: right;">  Weight (kg)</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">  1</td><td><img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1.png' alt='bulbasaur' </td><td>bulbasaur </td><td>grass, poison</td><td style="text-align: right;">  45</td><td style="text-align: right;">   49</td><td style="text-align: right;">   49</td><td style="text-align: right;">       65</td><td style="text-align: right;">       65</td><td style="text-align: right;">     45</td><td>overgrow, chlorophyll</td><td style="text-align: right;">           70</td><td style="text-align: right;">          6.9</td></tr>
# <tr><td style="text-align: right;">  2</td><td><img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/2.png' alt='ivysaur'   </td><td>ivysaur   </td><td>grass, poison</td><td style="text-align: right;">  60</td><td style="text-align: right;">   62</td><td style="text-align: right;">   63</td><td style="text-align: right;">       80</td><td style="text-align: right;">       80</td><td style="text-align: right;">     60</td><td>overgrow, chlorophyll</td><td style="text-align: right;">          100</td><td style="text-align: right;">         13  </td></tr>
# <tr><td style="text-align: right;">  3</td><td><img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/3.png' alt='venusaur'  </td><td>venusaur  </td><td>grass, poison</td><td style="text-align: right;">  80</td><td style="text-align: right;">   82</td><td style="text-align: right;">   83</td><td style="text-align: right;">      100</td><td style="text-align: right;">      100</td><td style="text-align: right;">     80</td><td>overgrow, chlorophyll</td><td style="text-align: right;">          200</td><td style="text-align: right;">        100  </td></tr>
# <tr><td style="text-align: right;">  4</td><td><img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/4.png' alt='charmander'</td><td>charmander</td><td>fire         </td><td style="text-align: right;">  39</td><td style="text-align: right;">   52</td><td style="text-align: right;">   43</td><td style="text-align: right;">       60</td><td style="text-align: right;">       50</td><td style="text-align: right;">     65</td><td>blaze, solar-power   </td><td style="text-align: right;">           60</td><td style="text-align: right;">          8.5</td></tr>
# <tr><td style="text-align: right;">  5</td><td><img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/5.png' alt='charmeleon'</td><td>charmeleon</td><td>fire         </td><td style="text-align: right;">  58</td><td style="text-align: right;">   64</td><td style="text-align: right;">   58</td><td style="text-align: right;">       80</td><td style="text-align: right;">       65</td><td style="text-align: right;">     80</td><td>blaze, solar-power   </td><td style="text-align: right;">          110</td><td style="text-align: right;">         19  </td></tr>
# <tr><td style="text-align: right;">  6</td><td><img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/6.png' alt='charizard' </td><td>charizard </td><td>fire, flying </td><td style="text-align: right;">  78</td><td style="text-align: right;">   84</td><td style="text-align: right;">   78</td><td style="text-align: right;">      109</td><td style="text-align: right;">       85</td><td style="text-align: right;">    100</td><td>blaze, solar-power   </td><td style="text-align: right;">          170</td><td style="text-align: right;">         90.5</td></tr>
# <tr><td style="text-align: right;">  7</td><td><img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/7.png' alt='squirtle'  </td><td>squirtle  </td><td>water        </td><td style="text-align: right;">  44</td><td style="text-align: right;">   48</td><td style="text-align: right;">   65</td><td style="text-align: right;">       50</td><td style="text-align: right;">       64</td><td style="text-align: right;">     43</td><td>torrent, rain-dish   </td><td style="text-align: right;">           50</td><td style="text-align: right;">          9  </td></tr>
# <tr><td style="text-align: right;">  8</td><td><img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/8.png' alt='wartortle' </td><td>wartortle </td><td>water        </td><td style="text-align: right;">  59</td><td style="text-align: right;">   63</td><td style="text-align: right;">   80</td><td style="text-align: right;">       65</td><td style="text-align: right;">       80</td><td style="text-align: right;">     58</td><td>torrent, rain-dish   </td><td style="text-align: right;">          100</td><td style="text-align: right;">         22.5</td></tr>
# <tr><td style="text-align: right;">  9</td><td><img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/9.png' alt='blastoise' </td><td>blastoise </td><td>water        </td><td style="text-align: right;">  79</td><td style="text-align: right;">   83</td><td style="text-align: right;">  100</td><td style="text-align: right;">       85</td><td style="text-align: right;">      105</td><td style="text-align: right;">     78</td><td>torrent, rain-dish   </td><td style="text-align: right;">          160</td><td style="text-align: right;">         85.5</td></tr>
# </tbody>
# </table>

# %% [markdown]
# # Print using JSON

# %%
from IPython.display import HTML, display
import tabulate, json , collections

all_pokemons_info = json.load(open("data/all_pokemons_info.json", "r"))
all_pokemons_info = {k:collections.defaultdict(str, v) for k,v in all_pokemons_info.items()}
content = [["#", "Sprite", "Name", "Types", 
            "HP", "Att", "Def", "Sp. Att", "Sp. Def", "Speed", 
            "Abilities", "Height (cm)", "Weight (kg)",
            "Capture Rate", "Base Happiness",
            "Growth Rate", "Generation",
            "Evolves from", "Evolves to"
           ]]
for i, (pokemon, info) in enumerate(all_pokemons_info.items()):
    try:
        content.append([i+1,
                        f"<img src='{info['sprites']}' alt='{pokemon}'",
                        pokemon,
                        "<br>".join(info["types"]),
                        info["hp"],
                        info["attack"],
                        info["defense"],
                        info["special-attack"],
                        info["special-defense"],
                        info["speed"],
                        "<br>".join(info["abilities"]),
                        info["height"]*10,
                        info["weight"]/10,
                        info["capture_rate"],
                        info["base_happiness"],
                        info["growth_rate"],
                        info["generation"],
                        info["evolves_from"],
                        "<br>".join(info["evolves_to"]),
                     ])
    except:
        print(pokemon, end=", ")

display(HTML(tabulate.tabulate(content, 
                               headers='firstrow', 
                               tablefmt='html',
                               numalign='center',
                               stralign='center',
                               
                              )))
# Out:
# exeggutor, deoxys, wormadam, giratina, shaymin, basculin, darmanitan, tornadus, thundurus, landorus, keldeo, meloetta, meowstic, aegislash, pumpkaboo, gourgeist, oricorio, lycanroc, wishiwashi, minior, mimikyu, toxtricity, eiscue, indeedee, zacian, zamazenta, urshifu,
# <table>
# <thead>
# <tr><th style="text-align: center;"> #  </th><th style="text-align: center;">                                                            Sprite                                                            </th><th style="text-align: center;">           Name           </th><th style="text-align: center;">       Types       </th><th style="text-align: center;"> HP </th><th style="text-align: center;"> Att </th><th style="text-align: center;"> Def </th><th style="text-align: center;"> Sp. Att </th><th style="text-align: center;"> Sp. Def </th><th style="text-align: center;"> Speed </th><th style="text-align: center;">                 Abilities                  </th><th style="text-align: center;"> Height (cm) </th><th style="text-align: center;"> Weight (kg) </th><th style="text-align: center;"> Capture Rate </th><th style="text-align: center;"> Base Happiness </th><th style="text-align: center;">    Growth Rate    </th><th style="text-align: center;"> Generation </th><th style="text-align: center;"> Evolves from </th><th style="text-align: center;">                                     Evolves to                                     </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: center;"> 1  </td><td style="text-align: center;">          <img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1.png' alt='bulbasaur'           </td><td style="text-align: center;">        bulbasaur         </td><td style="text-align: center;">  grass<br>poison  </td><td style="text-align: center;"> 45 </td><td style="text-align: center;"> 49  </td><td style="text-align: center;"> 49  </td><td style="text-align: center;">   65    </td><td style="text-align: center;">   65    </td><td style="text-align: center;">  45   </td><td style="text-align: center;">          overgrow<br>chlorophyll           </td><td style="text-align: center;">     70      </td><td style="text-align: center;">     6.9     </td><td style="text-align: center;">      45      </td><td style="text-align: center;">       70       </td><td style="text-align: center;">    medium-slow    </td><td style="text-align: center;">     I      </td><td style="text-align: center;">              </td><td style="text-align: center;">                                      ivysaur                                       </td></tr>
# <tr><td style="text-align: center;"> 2  </td><td style="text-align: center;">           <img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/2.png' alt='ivysaur'            </td><td style="text-align: center;">         ivysaur          </td><td style="text-align: center;">  grass<br>poison  </td><td style="text-align: center;"> 60 </td><td style="text-align: center;"> 62  </td><td style="text-align: center;"> 63  </td><td style="text-align: center;">   80    </td><td style="text-align: center;">   80    </td><td style="text-align: center;">  60   </td><td style="text-align: center;">          overgrow<br>chlorophyll           </td><td style="text-align: center;">     100     </td><td style="text-align: center;">     13      </td><td style="text-align: center;">      45      </td><td style="text-align: center;">       70       </td><td style="text-align: center;">    medium-slow    </td><td style="text-align: center;">     I      </td><td style="text-align: center;">  bulbasaur   </td><td style="text-align: center;">                                      venusaur                                      </td></tr>
# <tr><td style="text-align: center;"> 3  </td><td style="text-align: center;">           <img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/3.png' alt='venusaur'           </td><td style="text-align: center;">         venusaur         </td><td style="text-align: center;">  grass<br>poison  </td><td style="text-align: center;"> 80 </td><td style="text-align: center;"> 82  </td><td style="text-align: center;"> 83  </td><td style="text-align: center;">   100   </td><td style="text-align: center;">   100   </td><td style="text-align: center;">  80   </td><td style="text-align: center;">          overgrow<br>chlorophyll           </td><td style="text-align: center;">     200     </td><td style="text-align: center;">     100     </td><td style="text-align: center;">      45      </td><td style="text-align: center;">       70       </td><td style="text-align: center;">    medium-slow    </td><td style="text-align: center;">     I      </td><td style="text-align: center;">   ivysaur    </td><td style="text-align: center;">                                                                                    </td></tr>
# <tr><td style="text-align: center;"> 4  </td><td style="text-align: center;">          <img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/4.png' alt='charmander'          </td><td style="text-align: center;">        charmander        </td><td style="text-align: center;">       fire        </td><td style="text-align: center;"> 39 </td><td style="text-align: center;"> 52  </td><td style="text-align: center;"> 43  </td><td style="text-align: center;">   60    </td><td style="text-align: center;">   50    </td><td style="text-align: center;">  65   </td><td style="text-align: center;">            blaze<br>solar-power            </td><td style="text-align: center;">     60      </td><td style="text-align: center;">     8.5     </td><td style="text-align: center;">      45      </td><td style="text-align: center;">       70       </td><td style="text-align: center;">    medium-slow    </td><td style="text-align: center;">     I      </td><td style="text-align: center;">              </td><td style="text-align: center;">                                     charmeleon                                     </td></tr>
# <tr><td style="text-align: center;"> 5  </td><td style="text-align: center;">          <img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/5.png' alt='charmeleon'          </td><td style="text-align: center;">        charmeleon        </td><td style="text-align: center;">       fire        </td><td style="text-align: center;"> 58 </td><td style="text-align: center;"> 64  </td><td style="text-align: center;"> 58  </td><td style="text-align: center;">   80    </td><td style="text-align: center;">   65    </td><td style="text-align: center;">  80   </td><td style="text-align: center;">            blaze<br>solar-power            </td><td style="text-align: center;">     110     </td><td style="text-align: center;">     19      </td><td style="text-align: center;">      45      </td><td style="text-align: center;">       70       </td><td style="text-align: center;">    medium-slow    </td><td style="text-align: center;">     I      </td><td style="text-align: center;">  charmander  </td><td style="text-align: center;">                                     charizard                                      </td></tr>
# <tr><td style="text-align: center;"> 6  </td><td style="text-align: center;">          <img src='https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/6.png' alt='charizard'           </td><td style="text-align: center;">        charizard         </td><td style="text-align: center;">  fire<br>flying   </td><td style="text-align: center;"> 78 </td><td style="text-align: center;"> 84  </td><td style="text-align: center;"> 78  </td><td style="text-align: center;">   109   </td><td style="text-align: center;">   85    </td><td style="text-align: center;">  100  </td><td style="text-align: center;">            blaze<br>solar-power            </td><td style="text-align: center;">     170     </td><td style="text-align: center;">    90.5     </td><td style="text-align: center;">      45      </td><td style="text-align: center;">       70       </td><td style="text-align: center;">    medium-slow    </td><td style="text-align: center;">     I      </td><td style="text-align: center;">  charmeleon  </td><t
